# %% [markdown]
# <a href="https://colab.research.google.com/github/rajr550/Pytorch-tutorial/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------------
# absl-py                   1.4.0
# accelerate                1.10.1
# aiofiles                  25.1.0
# altair                    5.5.0
# annotated-types           0.7.0
# anyio                     4.11.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# array_record              0.8.1
# arrow                     1.3.0
# attrs                     25.4.0
# audioread                 3.0.1
# backcall                  0.2.0
# beartype                  0.22.2
# beautifulsoup4            4.13.5
# betterproto               2.0.0b6
# bleach                    6.2.0
# blinker                   1.4
# blis                      1.3.0
# cachetools                5.5.2
# catalogue                 2.0.10
# certifi                   2025.10.5
# cffi                      2.0.0
# charset-normalizer        3.4.4
# chex                      0.1.90
# click                     8.3.0
# ...
